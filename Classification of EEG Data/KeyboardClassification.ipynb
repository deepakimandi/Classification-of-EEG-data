# %%
import pandas as pd
import numpy as np
import math
import csv
import itertools
import random
from pprint import pprint

dataset = []
temp_data = []
temp_row = []
header = ['Theta1', 'Alpha1', 'Low_beta1', 'High_beta1', 'Gamma1', 'tbhb1', 'tblb1', 'abhb1', 'ablb1',
          'Theta2', 'Alpha2', 'Low_beta2', 'High_beta2', 'Gamma2', 'tbhb2', 'tblb2', 'abhb2', 'ablb2',
          'Theta3', 'Alpha3', 'Low_beta3', 'High_beta3', 'Gamma3', 'tbhb3', 'tblb3', 'abhb3', 'ablb3',
          'Theta4', 'Alpha4', 'Low_beta4', 'High_beta4', 'Gamma4', 'tbhb4', 'tblb4', 'abhb4', 'ablb4',
          'Theta5', 'Alpha5', 'Low_beta5', 'High_beta5', 'Gamma5', 'tbhb5', 'tblb5', 'abhb5', 'ablb5', 'Target']
for i in range(1, 6):
    with open("abdul_keyboard" + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [0])
                    j = 0
                    temp_row.clear()

# print(temp_data[0])
dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()


for i in range(1, 6):
    with open("alaa_keyboard" + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        if i == 3:
            for row in data:
                if len(row) == 5 and row[0] != 'Theta':
#                     row.pop()
                    for x in range(0, 4):
                        row[x] = float(row[x].strip())
                    row.append(row[0]/row[3])
                    row.append(row[0]/row[2])
                    row.append(row[1]/row[3])
                    row.append(row[1]/row[2])
    #                 row.append(0)
                    temp_row.append(row)
                    j = j + 1
                    if j == 5:
                        temp_data.append(list(itertools.chain(*temp_row)) + [0])
                        j = 0
                        temp_row.clear()
        else:
            for row in data:
                if len(row) == 6:
                    row.pop()
                    for x in range(0, 5):
                        row[x] = float(row[x].strip())
                    row.append(row[0]/row[3])
                    row.append(row[0]/row[2])
                    row.append(row[1]/row[3])
                    row.append(row[1]/row[2])
    #                 row.append(0)
                    temp_row.append(row)
                    j = j + 1
                    if j == 5:
                        temp_data.append(list(itertools.chain(*temp_row)) + [0])
                        j = 0
                        temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()


for i in range(1, 6):
    with open("ali_keyboard" + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [0])
                    j = 0
                    temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()

for i in range(1, 6):
    with open("amer_keyboard" + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [0])
                    j = 0
                    temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()

for i in range(1, 6):
    with open("sharno_keyboard" + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [0])
                    j = 0
                    temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()

for i in range(1, 7):
    with open("ayse nur key " + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [1])
                    j = 0
                    temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()

for i in range(1, 7):
    with open("Humam Key " + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [1])
                    j = 0
                    temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()

for i in range(1, 7):
    with open("key said " + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    temp_data.append(list(itertools.chain(*temp_row)) + [1])
                    j = 0
                    temp_row.clear()

dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()
# count = 0
for i in range(1, 7):
    with open("key zeynep " + str(i) + ".csv") as data_File:
        data = csv.reader(data_File)
        j = 0
        for row in data:
            if len(row) == 6:
                row.pop()
                for x in range(0, 5):
                    row[x] = float(row[x].strip())
                if row[2] == 0 or row[3] == 0:
#                     count = count + 1
                    continue
                row.append(row[0]/row[3])
                row.append(row[0]/row[2])
                row.append(row[1]/row[3])
                row.append(row[1]/row[2])
#                 row.append(0)
                temp_row.append(row)
                j = j + 1
                if j == 5:
                    if len(list(itertools.chain(*temp_row)) + [1]) == 46:
                        temp_data.append(list(itertools.chain(*temp_row)) + [1])
                    j = 0
                    temp_row.clear()


dataset = dataset + temp_data
# print(len(temp_data))
temp_data.clear()

# pprint(dataset)
# print(len(dataset) )
dataset.sort()
dataset = list(dataset for dataset,_ in itertools.groupby(dataset))
random.shuffle(dataset)

df = pd.DataFrame(dataset, columns = header)
df['Theta1'] = df['Theta1'].astype('float')
df['Alpha1'] = df['Alpha1'].astype('float')
df['Low_beta1'] = df['Low_beta1'].astype('float')
df['High_beta1'] = df['High_beta1'].astype('float')
df['Gamma1'] = df['Gamma1'].astype('float')
df['Theta2'] = df['Theta2'].astype('float')
df['Alpha2'] = df['Alpha2'].astype('float')
df['Low_beta2'] = df['Low_beta2'].astype('float')
df['High_beta2'] = df['High_beta2'].astype('float')
df['Gamma2'] = df['Gamma2'].astype('float')
df['Theta3'] = df['Theta3'].astype('float')
df['Alpha3'] = df['Alpha3'].astype('float')
df['Low_beta3'] = df['Low_beta3'].astype('float')
df['High_beta3'] = df['High_beta3'].astype('float')
df['Gamma3'] = df['Gamma3'].astype('float')
df['Theta4'] = df['Theta4'].astype('float')
df['Alpha4'] = df['Alpha4'].astype('float')
df['Low_beta4'] = df['Low_beta4'].astype('float')
df['High_beta4'] = df['High_beta4'].astype('float')
df['Gamma4'] = df['Gamma4'].astype('float')
df['Theta5'] = df['Theta5'].astype('float')
df['Alpha5'] = df['Alpha5'].astype('float')
df['Low_beta5'] = df['Low_beta5'].astype('float')
df['High_beta5'] = df['High_beta5'].astype('float')
df['Gamma5'] = df['Gamma5'].astype('float')
df['tbhb1'] = df['tbhb1'].astype('float')
df['tblb1'] = df['tblb1'].astype('float')
df['abhb1'] = df['abhb1'].astype('float')
df['ablb1'] = df['ablb1'].astype('float')
df['tbhb2'] = df['tbhb2'].astype('float')
df['tblb2'] = df['tblb2'].astype('float')
df['abhb2'] = df['abhb2'].astype('float')
df['ablb2'] = df['ablb2'].astype('float')
df['tbhb3'] = df['tbhb3'].astype('float')
df['tblb3'] = df['tblb3'].astype('float')
df['abhb3'] = df['abhb3'].astype('float')
df['ablb3'] = df['ablb3'].astype('float')
df['tbhb4'] = df['tbhb4'].astype('float')
df['tblb4'] = df['tblb4'].astype('float')
df['abhb4'] = df['abhb4'].astype('float')
df['ablb4'] = df['ablb4'].astype('float')
df['tbhb5'] = df['tbhb5'].astype('float')
df['tblb5'] = df['tblb5'].astype('float')
df['abhb5'] = df['abhb5'].astype('float')
df['ablb5'] = df['ablb5'].astype('float')
# df.dtypes
print('Number of data samples : ' + str(len(df)))
# df
# Out:
# Number of data samples : 4860

# %%
y = df.Target
X = df.drop(['Target'], axis = 'columns')

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# modelSVM = SVC(C=1000, gamma=0.001)
# modelSVM.fit(X_train, y_train)

modelRFC = RandomForestClassifier(n_estimators = 60)
modelRFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=60)

# %%
print('Accuracy : ' + str(modelRFC.score(X_test, y_test)))

from statistics import mean
from sklearn.model_selection import cross_val_score
result = cross_val_score(modelRFC, X, y)
print('Accuracies on applying 5-fold cross-validation : ' + str(result))
print('Mean accuracy : ' + str(mean(result)))
# Out:
# Accuracy : 0.9621399176954732
# Accuracies on applying 5-fold cross-validation : [0.96502058 0.96296296 0.96604938 0.96604938 0.97119342]
# Mean accuracy : 0.9662551440329218

# %%
y_predicted = modelRFC.predict(X_test)
print('Number of test samples : ' + str(len(X_test)))
# Out:
# Number of test samples : 1215

# %%
from sklearn.metrics import confusion_matrix
conmat = confusion_matrix(y_test, y_predicted)
conmat
# Out:
# array([[666,  10],
#        [ 36, 503]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize = (3, 2))
axes = sn.heatmap(conmat, annot = True, fmt = 'd', cbar=False, cmap=plt.cm.GnBu)
plt.xlabel('Predicted', color = '#000000', fontsize = 12)
plt.ylabel('Actual', color = '#000000', fontsize = 12)
class_labels = ['0', '1']
axes.set_title('Confusion Matrix:Keyboard data', color = '#000000', fontsize = 12, fontstyle = 'italic')
axes.set_xticklabels(class_labels, color = '#000000', fontsize = 12)
axes.set_yticklabels(class_labels,rotation=0, color = '#000000', fontsize = 12)
# Out:
# [Text(0, 0.5, '0'), Text(0, 1.5, '1')]
